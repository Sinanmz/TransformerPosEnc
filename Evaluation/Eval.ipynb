# %%
import csv

from google.colab import drive
drive.mount('/content/drive')




EncoderTrainLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderTrainLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderTrainLosses.append(number)

EncoderTestLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderTestLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderTestLosses.append(number)

EncoderTrainAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderTrainAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderTrainAccuracy.append(number)

EncoderTestAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderTestAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderTestAccuracy.append(number)




DecoderTrainLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderTrainLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderTrainLosses.append(number)

DecoderTestLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderTestLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderTestLosses.append(number)

DecoderTrainAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderTrainAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderTrainAccuracy.append(number)

DecoderTestAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderTestAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderTestAccuracy.append(number)




EncoderPosEncTrainLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncTrainLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncTrainLosses.append(number)

EncoderPosEncTestLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncTestLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncTestLosses.append(number)

EncoderPosEncTrainAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncTrainAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncTrainAccuracy.append(number)

EncoderPosEncTestAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncTestAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncTestAccuracy.append(number)





DecoderPosEncTrainLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncTrainLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncTrainLosses.append(number)

DecoderPosEncTestLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncTestLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncTestLosses.append(number)

DecoderPosEncTrainAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncTrainAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncTrainAccuracy.append(number)

DecoderPosEncTestAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncTestAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncTestAccuracy.append(number)



EncoderPosEncWaveTrainLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncWaveTrainLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncWaveTrainLosses.append(number)

EncoderPosEncWaveTestLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncWaveTestLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncWaveTestLosses.append(number)

EncoderPosEncWaveTrainAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncWaveTrainAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncWaveTrainAccuracy.append(number)

EncoderPosEncWaveTestAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/EncoderPosEncWaveTestAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        EncoderPosEncWaveTestAccuracy.append(number)



DecoderPosEncWaveTrainLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncWaveTrainLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncWaveTrainLosses.append(number)

DecoderPosEncWaveTestLosses = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncWaveTestLosses.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncWaveTestLosses.append(number)

DecoderPosEncWaveTrainAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncWaveTrainAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncWaveTrainAccuracy.append(number)

DecoderPosEncWaveTestAccuracy = []
with open('/content/drive/MyDrive/transformer/Evaluation/DecoderPosEncWaveTestAccuracy.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        number = float(row[0])
        DecoderPosEncWaveTestAccuracy.append(number)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
loss_eval = [(EncoderTrainLosses, EncoderTestLosses), (DecoderTrainLosses, DecoderTestLosses),
             (EncoderPosEncTrainLosses, EncoderPosEncTestLosses), (DecoderPosEncTrainLosses, DecoderPosEncTestLosses),
             (EncoderPosEncWaveTrainLosses, EncoderPosEncWaveTestLosses), (DecoderPosEncWaveTrainLosses, DecoderPosEncWaveTestLosses)]

accuracy_eval = [(EncoderTrainAccuracy, EncoderTestAccuracy), (DecoderTrainAccuracy, DecoderTestAccuracy),
                 (EncoderPosEncTrainAccuracy, EncoderPosEncTestAccuracy), (DecoderPosEncTrainAccuracy, DecoderPosEncTestAccuracy),
                 (EncoderPosEncWaveTrainAccuracy, EncoderPosEncWaveTestAccuracy), (DecoderPosEncWaveTrainAccuracy, DecoderPosEncWaveTestAccuracy)]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 18))


plt.subplot(3, 2, 1)
plt.plot([i/2 for i in range(0, 21)], EncoderTrainLosses, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], EncoderTestLosses, label = "Test Loss")
plt.scatter(EncoderTestLosses.index(min(EncoderTestLosses))/2, min(EncoderTestLosses), color='red', label='Minimum Test Loss')
plt.annotate(f'{min(EncoderTestLosses):.3f}', (EncoderTestLosses.index(min(EncoderTestLosses))/2, min(EncoderTestLosses)))
plt.title("Encoder Without Positional Encoding")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Loss")
plt.ylim(0, 1)
plt.legend()


plt.subplot(3, 2, 2)
plt.plot([i/2 for i in range(0, 21)], DecoderTrainLosses, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], DecoderTestLosses, label = "Test Loss")
plt.scatter(DecoderTestLosses.index(min(DecoderTestLosses))/2, min(DecoderTestLosses), color='red', label='Minimum Test Loss')
plt.annotate(f'{min(DecoderTestLosses):.3f}', (DecoderTestLosses.index(min(DecoderTestLosses))/2, min(DecoderTestLosses)))
plt.title("Decoder Without Positional Encoding")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Loss")
plt.ylim(0, 1)
plt.legend()


plt.subplot(3, 2, 3)
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncTrainLosses, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncTestLosses, label = "Test Loss")
plt.scatter(EncoderPosEncTestLosses.index(min(EncoderPosEncTestLosses))/2, min(EncoderPosEncTestLosses), color='red', label='Minimum Test Loss')
plt.annotate(f'{min(EncoderPosEncTestLosses):.3f}', (EncoderPosEncTestLosses.index(min(EncoderPosEncTestLosses))/2, min(EncoderPosEncTestLosses)))
plt.title("Encoder With Positional Encoding With Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Loss")
plt.ylim(0, 1)
plt.legend()

plt.subplot(3, 2, 4)
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncTrainLosses, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncTestLosses, label = "Test Loss")
plt.scatter(DecoderPosEncTestLosses.index(min(DecoderPosEncTestLosses))/2, min(DecoderPosEncTestLosses), color='red', label='Minimum Test Loss')
plt.annotate(f'{min(DecoderPosEncTestLosses):.3f}', (DecoderPosEncTestLosses.index(min(DecoderPosEncTestLosses))/2, min(DecoderPosEncTestLosses)))
plt.title("Decoder With Positional Encoding With Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Loss")
plt.ylim(0, 1)
plt.legend()

plt.subplot(3, 2, 5)
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncWaveTrainLosses, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncWaveTestLosses, label = "Test Loss")
plt.scatter(EncoderPosEncWaveTestLosses.index(min(EncoderPosEncWaveTestLosses))/2, min(EncoderPosEncWaveTestLosses), color='red', label='Minimum Test Loss')
plt.annotate(f'{min(EncoderPosEncWaveTestLosses):.3f}', (EncoderPosEncWaveTestLosses.index(min(EncoderPosEncWaveTestLosses))/2, min(EncoderPosEncWaveTestLosses)))
plt.title("Encoder With Positional Encoding Without Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Loss")
plt.ylim(0, 1)
plt.legend()

plt.subplot(3, 2, 6)
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncWaveTrainLosses, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncWaveTestLosses, label = "Test Loss")
plt.scatter(DecoderPosEncWaveTestLosses.index(min(DecoderPosEncWaveTestLosses))/2, min(DecoderPosEncWaveTestLosses), color='red', label='Minimum Test Loss')
plt.annotate(f'{min(DecoderPosEncWaveTestLosses):.3f}', (DecoderPosEncWaveTestLosses.index(min(DecoderPosEncWaveTestLosses))/2, min(DecoderPosEncWaveTestLosses)))
plt.title("Decoder With Positional Encoding Without Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Loss")
plt.ylim(0, 1)
plt.legend()


plt.show()

# %%
plt.figure(figsize=(14, 10))


plt.subplot(2, 1, 1)
plt.plot([i/2 for i in range(0, 21)], EncoderTestLosses, label = "Encoder W/O Pos Enc", color = 'red')
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncTestLosses, label = "Encoder W/ Pos Enc W/ Learnable Params", color = 'blue')
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncWaveTestLosses, label = "Encoder W/ Pos Enc W/O Learnable Params", color = 'green')
plt.scatter(EncoderTestLosses.index(min(EncoderTestLosses))/2, min(EncoderTestLosses), color='red')
plt.scatter(EncoderPosEncTestLosses.index(min(EncoderPosEncTestLosses))/2, min(EncoderPosEncTestLosses), color='blue')
plt.scatter(EncoderPosEncWaveTestLosses.index(min(EncoderPosEncWaveTestLosses))/2, min(EncoderPosEncWaveTestLosses), color='green')
plt.annotate(f'{min(EncoderTestLosses):.3f}', (EncoderTestLosses.index(min(EncoderTestLosses))/2, min(EncoderTestLosses)))
plt.annotate(f'{min(EncoderPosEncTestLosses):.3f}', (EncoderPosEncTestLosses.index(min(EncoderPosEncTestLosses))/2, min(EncoderPosEncTestLosses)))
plt.annotate(f'{min(EncoderPosEncWaveTestLosses):.3f}', (EncoderPosEncWaveTestLosses.index(min(EncoderPosEncWaveTestLosses))/2, min(EncoderPosEncWaveTestLosses)))
plt.title("Encoder Group")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Test Loss")
plt.ylim(0, 1)
plt.legend()


plt.subplot(2, 1, 2)
plt.plot([i/2 for i in range(0, 21)], DecoderTestLosses, label = "Decoder W/O Pos Enc", color = 'red')
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncTestLosses, label = "Decoder W/ Pos Enc W/ Learnable Params", color = 'blue')
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncWaveTestLosses, label = "Decoder W/ Pos Enc W/O Learnable Params", color = 'green')
plt.scatter(DecoderTestLosses.index(min(DecoderTestLosses))/2, min(DecoderTestLosses), color='red')
plt.scatter(DecoderPosEncTestLosses.index(min(DecoderPosEncTestLosses))/2, min(DecoderPosEncTestLosses), color='blue')
plt.scatter(DecoderPosEncWaveTestLosses.index(min(DecoderPosEncWaveTestLosses))/2, min(DecoderPosEncWaveTestLosses), color='green')
plt.annotate(f'{min(DecoderTestLosses):.3f}', (DecoderTestLosses.index(min(DecoderTestLosses))/2, min(DecoderTestLosses)))
plt.annotate(f'{min(DecoderPosEncTestLosses):.3f}', (DecoderPosEncTestLosses.index(min(DecoderPosEncTestLosses))/2, min(DecoderPosEncTestLosses)))
plt.annotate(f'{min(DecoderPosEncWaveTestLosses):.3f}', (DecoderPosEncWaveTestLosses.index(min(DecoderPosEncWaveTestLosses))/2, min(DecoderPosEncWaveTestLosses)))
plt.title("Decoder Group")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Binary Cross-Entropy Test Loss")
plt.ylim(0, 1)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(16, 18))


plt.subplot(3, 2, 1)
plt.plot([i/2 for i in range(0, 21)], EncoderTrainAccuracy, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], EncoderTestAccuracy, label = "Test Loss")
plt.scatter(EncoderTestAccuracy.index(max(EncoderTestAccuracy))/2, max(EncoderTestAccuracy), color='red', label='Maximum Test Accuracy')
plt.annotate(f'{max(EncoderTestAccuracy):.3f}', (EncoderTestAccuracy.index(max(EncoderTestAccuracy))/2, max(EncoderTestAccuracy)))
plt.title("Encoder Without Positional Encoding")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()


plt.subplot(3, 2, 2)
plt.plot([i/2 for i in range(0, 21)], DecoderTrainAccuracy, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], DecoderTestAccuracy, label = "Test Loss")
plt.scatter(DecoderTestAccuracy.index(max(DecoderTestAccuracy))/2, max(DecoderTestAccuracy), color='red', label='Maximum Test Accuracy')
plt.annotate(f'{max(DecoderTestAccuracy):.3f}', (DecoderTestAccuracy.index(max(DecoderTestAccuracy))/2, max(DecoderTestAccuracy)))
plt.title("Decoder Without Positional Encoding")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()


plt.subplot(3, 2, 3)
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncTrainAccuracy, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncTestAccuracy, label = "Test Loss")
plt.scatter(EncoderPosEncTestAccuracy.index(max(EncoderPosEncTestAccuracy))/2, max(EncoderPosEncTestAccuracy), color='red', label='Maximum Test Accuracy')
plt.annotate(f'{max(EncoderPosEncTestAccuracy):.3f}', (EncoderPosEncTestAccuracy.index(max(EncoderPosEncTestAccuracy))/2, max(EncoderPosEncTestAccuracy)))
plt.title("Encoder With Positional Encoding With Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()

plt.subplot(3, 2, 4)
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncTrainAccuracy, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncTestAccuracy, label = "Test Loss")
plt.scatter(DecoderPosEncTestAccuracy.index(max(DecoderPosEncTestAccuracy))/2, max(DecoderPosEncTestAccuracy), color='red', label='Maximum Test Accuracy')
plt.annotate(f'{max(DecoderPosEncTestAccuracy):.3f}', (DecoderPosEncTestAccuracy.index(max(DecoderPosEncTestAccuracy))/2, max(DecoderPosEncTestAccuracy)))
plt.title("Decoder With Positional Encoding With Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()


plt.subplot(3, 2, 5)
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncWaveTrainAccuracy, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncWaveTestAccuracy, label = "Test Loss")
plt.scatter(EncoderPosEncWaveTestAccuracy.index(max(EncoderPosEncWaveTestAccuracy))/2, max(EncoderPosEncWaveTestAccuracy), color='red', label='Maximum Test Accuracy')
plt.annotate(f'{max(EncoderPosEncWaveTestAccuracy):.3f}', (EncoderPosEncWaveTestAccuracy.index(max(EncoderPosEncWaveTestAccuracy))/2, max(EncoderPosEncWaveTestAccuracy)))
plt.title("Encoder With Positional Encoding Without Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()

plt.subplot(3, 2, 6)
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncWaveTrainAccuracy, label = "Train Loss")
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncWaveTestAccuracy, label = "Test Loss")
plt.scatter(DecoderPosEncWaveTestAccuracy.index(max(DecoderPosEncWaveTestAccuracy))/2, max(DecoderPosEncWaveTestAccuracy), color='red', label='Maximum Test Accuracy')
plt.annotate(f'{max(DecoderPosEncWaveTestAccuracy):.3f}', (DecoderPosEncWaveTestAccuracy.index(max(DecoderPosEncWaveTestAccuracy))/2, max(DecoderPosEncWaveTestAccuracy)))
plt.title("Decoder With Positional Encoding Without Learnable Parameters")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(16, 10))


plt.subplot(2, 1, 1)
plt.plot([i/2 for i in range(0, 21)], EncoderTestAccuracy, label = "Encoder W/O Pos Enc", color = 'red')
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncTestAccuracy, label = "Encoder W/ Pos Enc W/ Learnable Params", color = 'blue')
plt.plot([i/2 for i in range(0, 21)], EncoderPosEncWaveTestAccuracy, label = "Encoder W/ Pos Enc W/O Learnable Params", color = 'green')
plt.scatter(EncoderTestAccuracy.index(max(EncoderTestAccuracy))/2, max(EncoderTestAccuracy), color='red')
plt.scatter(EncoderPosEncTestAccuracy.index(max(EncoderPosEncTestAccuracy))/2, max(EncoderPosEncTestAccuracy), color='blue')
plt.scatter(EncoderPosEncWaveTestAccuracy.index(max(EncoderPosEncWaveTestAccuracy))/2, max(EncoderPosEncWaveTestAccuracy), color='green')
plt.annotate(f'{max(EncoderTestAccuracy):.3f}', (EncoderTestAccuracy.index(max(EncoderTestAccuracy))/2, max(EncoderTestAccuracy)))
plt.annotate(f'{max(EncoderPosEncTestAccuracy):.3f}', (EncoderPosEncTestAccuracy.index(max(EncoderPosEncTestAccuracy))/2, max(EncoderPosEncTestAccuracy)-0.03))
plt.annotate(f'{max(EncoderPosEncWaveTestAccuracy):.3f}', (EncoderPosEncWaveTestAccuracy.index(max(EncoderPosEncWaveTestAccuracy))/2, max(EncoderPosEncWaveTestAccuracy)+0.02))
plt.title("Encoder Group")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Test Accuracy")
plt.ylim(0, 1)
plt.legend()


plt.subplot(2, 1, 2)
plt.plot([i/2 for i in range(0, 21)], DecoderTestAccuracy, label = "Decoder W/O Pos Enc", color = 'red')
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncTestAccuracy, label = "Decoder W/ Pos Enc W/ Learnable Params", color = 'blue')
plt.plot([i/2 for i in range(0, 21)], DecoderPosEncWaveTestAccuracy, label = "Decoder W/ Pos Enc W/O Learnable Params", color = 'green')
plt.scatter(DecoderTestAccuracy.index(max(DecoderTestAccuracy))/2, max(DecoderTestAccuracy), color='red')
plt.scatter(DecoderPosEncTestAccuracy.index(max(DecoderPosEncTestAccuracy))/2, max(DecoderPosEncTestAccuracy), color='blue')
plt.scatter(DecoderPosEncWaveTestAccuracy.index(max(DecoderPosEncWaveTestAccuracy))/2, max(DecoderPosEncWaveTestAccuracy), color='green')
plt.annotate(f'{max(DecoderTestAccuracy):.3f}', (DecoderTestAccuracy.index(max(DecoderTestAccuracy))/2, max(DecoderTestAccuracy)))
plt.annotate(f'{max(DecoderPosEncTestAccuracy):.3f}', (DecoderPosEncTestAccuracy.index(max(DecoderPosEncTestAccuracy))/2, max(DecoderPosEncTestAccuracy)))
plt.annotate(f'{max(DecoderPosEncWaveTestAccuracy):.3f}', (DecoderPosEncWaveTestAccuracy.index(max(DecoderPosEncWaveTestAccuracy))/2, max(DecoderPosEncWaveTestAccuracy)))
plt.title("Decoder Group")
plt.xlabel("Epochs")
plt.xlim(0, 11)
plt.ylabel("Test Accuracy")
plt.ylim(0, 1)
plt.legend()

# %%
print("Encoder:          ", EncoderTestLosses)
print("Decoder:          ", DecoderTestLosses)
print("EncoderPosEnc:    ", EncoderPosEncTestLosses)
print("DecoderPosEnc:    ", DecoderPosEncTestLosses)
print("EncoderPosEncWave:", EncoderPosEncWaveTestLosses)
print("DecoderPosEncWave:", DecoderPosEncWaveTestLosses)
# Out:
# Encoder:           [0.719140339882002, 0.6389754141142608, 0.5880962919204606, 0.5942256543614449, 0.5850571711129005, 0.5787952066561498, 0.6425412663626014, 0.6465234597888562, 0.6471906550433657, 0.667769280595517, 0.6674309225257383, 0.720997518902525, 0.6880910440322456, 0.6925742035612054, 0.7091341051486654, 0.7328623680893435, 0.7131882599734385, 0.7496626054475067, 0.8122007321873936, 0.7754077911376953, 0.7975857842952834]
# Decoder:           [0.7183226171983491, 0.6306072746941803, 0.5946690292533384, 0.5736213747514497, 0.5460916998189523, 0.5705593922816286, 0.5614501822979079, 0.5850447213977849, 0.5660552568391922, 0.5756785038414352, 0.5780520400869738, 0.6456347403176333, 0.6006755470682722, 0.608273867073409, 0.5999988733081643, 0.6384824033177227, 0.6426116053117524, 0.6418055022528412, 0.6785056552755724, 0.6859511093262138, 0.6891814317178289]
# ...

# %%
print("Encoder:          ", EncoderTestAccuracy)
print("Decoder:          ", DecoderTestAccuracy)
print("EncoderPosEnc:    ", EncoderPosEncTestAccuracy)
print("DecoderPosEnc:    ", DecoderPosEncTestAccuracy)
print("EncoderPosEncWave:", EncoderPosEncWaveTestAccuracy)
print("DecoderPosEncWave:", DecoderPosEncWaveTestAccuracy)
# Out:
# Encoder:           [0.48394495412844035, 0.6513761467889908, 0.7247706422018348, 0.7522935779816514, 0.7798165137614679, 0.7844036697247706, 0.786697247706422, 0.7958715596330275, 0.8004587155963303, 0.7935779816513762, 0.7981651376146789, 0.8107798165137615, 0.801605504587156, 0.8107798165137615, 0.8096330275229358, 0.8073394495412844, 0.8073394495412844, 0.8073394495412844, 0.7958715596330275, 0.7958715596330275, 0.801605504587156]
# Decoder:           [0.47591743119266056, 0.6559633027522935, 0.7121559633027523, 0.7454128440366973, 0.7694954128440367, 0.768348623853211, 0.7809633027522935, 0.7889908256880734, 0.8027522935779816, 0.7935779816513762, 0.801605504587156, 0.7924311926605505, 0.805045871559633, 0.7993119266055045, 0.805045871559633, 0.7970183486238532, 0.8027522935779816, 0.8027522935779816, 0.8038990825688074, 0.8027522935779816, 0.801605504587156]
# ...

# %%
for (train, test) in loss_eval:
  print("Min Loss:", f'{min(test):.3f}', "At Epoch: ", test.index(min(test))/2)
# Out:
# Min Loss: 0.579 At Epoch:  2.5
# Min Loss: 0.546 At Epoch:  2.0
# Min Loss: 0.576 At Epoch:  2.0
# Min Loss: 0.574 At Epoch:  2.5
# Min Loss: 0.454 At Epoch:  5.5
# Min Loss: 0.462 At Epoch:  8.0

# %%
for (train, test) in accuracy_eval:
  print("Max Loss:", f'{max(test):.3f}', "At Epoch: ", test.index(max(test))/2)
# Out:
# Max Loss: 0.811 At Epoch:  5.5
# Max Loss: 0.805 At Epoch:  6.0
# Max Loss: 0.804 At Epoch:  10.0
# Max Loss: 0.802 At Epoch:  7.5
# Max Loss: 0.808 At Epoch:  10.0
# Max Loss: 0.813 At Epoch:  8.0
